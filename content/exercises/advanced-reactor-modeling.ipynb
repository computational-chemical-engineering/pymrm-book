# %% [markdown]
# # Advanced Reactor Modeling
#
# The Lecture 8 exercises focus on coupled model assembly. Each exercise starts from one lecture notebook and asks you to modify, validate, or compare the coupled model.
#
# **Exercise List**
#
# 1. [Pressure-velocity coupling in a 2D fixed-bed reactor](pressure-velocity-coupling-in-column-models.ipynb)
# 2. [Reactor-particle coupling](particle-model-coupled-to-column-model.ipynb)
# 3. [2D boundary surface-reaction coupling](surface-reaction-2d-boundary-coupling.ipynb)
# 4. [Monolithic 2D membrane module](monolithic-2d-membrane-module.ipynb)
# 5. [Reactor-particle coupling with Maxwell-Stefan film transfer](maxwell-stefan-particle-coupling.ipynb)
